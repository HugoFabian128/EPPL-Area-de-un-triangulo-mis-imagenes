# %% [markdown]
# <a href="https://colab.research.google.com/github/HugoFabian128/EPPL-Area-de-un-triangulo-mis-imagenes/blob/main/UII_Act_11_DF_%2B_codigo_Python_Hugo_Fabian_0040.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Hugo Fanian Antonio NL = 15 Fecha 25/Mar/2026
# ---
# # Clcular Area de un triangulo
# ![Logo de Markdown](https://raw.githubusercontent.com/HugoFabian128/EPPL-Area-de-un-triangulo-mis-imagenes/refs/heads/main/Area%20de%20un%20triangulo.webp)
# ---
# ### Formulas para calcular el Area
# $A=(b*h)/2$
# ---
# ## Datos de entrada
# $h$ ?
# $b$ ?
# ---
# ## diagrama de flujo lucidchart
# ![Logo de Markdown](https://raw.githubusercontent.com/HugoFabian128/EPPL-Area-de-un-triangulo-mis-imagenes/refs/heads/main/DF%20area%20de%20un%20triangulo.png)

# %%
# Calcular area de un triangulo
# Variables A, H, B
# formula A = (b * h) / 2
# Capturarael valor de A,H
import math
print("Calcular el Area de un triangulo")
B = float(input("Ingrese el valor de la base: "))
H = float(input("Ingrese el valor de la altura: "))

A = (B * H) / 2
print("El area del triangulo es: ", A)
print("Hugo Fabian NL = 15")
# Out:
# Calcular el Area de un triangulo
# Ingrese el valor de la base: 6
# Ingrese el valor de la altura: 7
# El area del triangulo es:  21.0
# Hugo Fabian NL = 15

# %% [markdown]
# # Relacion entre codigo y DF en Tldraw
# ![Logo de Markdown](https://raw.githubusercontent.com/HugoFabian128/EPPL-Area-de-un-triangulo-mis-imagenes/refs/heads/main/tldraw%20DF%20y%20codigo.PNG)
